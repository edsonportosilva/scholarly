# %% [markdown]
# <a href="https://colab.research.google.com/github/edsonportosilva/scholarly/blob/main/Jupyter/Google%20Scholar%20data.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
! pip3 install scholarly
# Out:
# Collecting scholarly
#   Downloading scholarly-1.7.11-py3-none-any.whl (39 kB)
# Collecting arrow (from scholarly)
#   Downloading arrow-1.2.3-py3-none-any.whl (66 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 66.4/66.4 kB 3.8 MB/s eta 0:00:00
# Requirement already satisfied: beautifulsoup4 in /usr/local/lib/python3.10/dist-packages (from scholarly) (4.11.2)
# Collecting bibtexparser (from scholarly)
#   Downloading bibtexparser-1.4.0.tar.gz (51 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 51.9/51.9 kB 7.9 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Collecting deprecated (from scholarly)
#   Downloading Deprecated-1.2.14-py2.py3-none-any.whl (9.6 kB)
# Collecting fake-useragent (from scholarly)
#   Downloading fake_useragent-1.2.1-py3-none-any.whl (14 kB)
# Collecting free-proxy (from scholarly)
#   Downloading free_proxy-1.1.1.tar.gz (5.1 kB)
#   Preparing metadata (setup.py) ... done
# Collecting httpx (from scholarly)
#   Downloading httpx-0.24.1-py3-none-any.whl (75 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 75.4/75.4 kB 10.5 MB/s eta 0:00:00
# Collecting python-dotenv (from scholarly)
#   Downloading python_dotenv-1.0.0-py3-none-any.whl (19 kB)
# Requirement already satisfied: requests[socks] in /usr/local/lib/python3.10/dist-packages (from scholarly) (2.31.0)
# Collecting selenium (from scholarly)
#   Downloading selenium-4.11.2-py3-none-any.whl (7.2 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.2/7.2 MB 24.8 MB/s eta 0:00:00
# Collecting sphinx-rtd-theme (from scholarly)
#   Downloading sphinx_rtd_theme-1.3.0-py2.py3-none-any.whl (2.8 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.8/2.8 MB 50.3 MB/s eta 0:00:00
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.10/dist-packages (from scholarly) (4.7.1)
# Requirement already satisfied: python-dateutil>=2.7.0 in /usr/local/lib/python3.10/dist-packages (from arrow->scholarly) (2.8.2)
# Requirement already satisfied: soupsieve>1.2 in /usr/local/lib/python3.10/dist-packages (from beautifulsoup4->scholarly) (2.4.1)
# Requirement already satisfied: pyparsing>=2.0.3 in /usr/local/lib/python3.10/dist-packages (from bibtexparser->scholarly) (3.1.1)
# Requirement already satisfied: wrapt<2,>=1.10 in /usr/local/lib/python3.10/dist-packages (from deprecated->scholarly) (1.14.1)
# Requirement already satisfied: lxml in /usr/local/lib/python3.10/dist-packages (from free-proxy->scholarly) (4.9.3)
# Requirement already satisfied: certifi in /usr/local/lib/python3.10/dist-packages (from httpx->scholarly) (2023.7.22)
# Collecting httpcore<0.18.0,>=0.15.0 (from httpx->scholarly)
#   Downloading httpcore-0.17.3-py3-none-any.whl (74 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 74.5/74.5 kB 10.7 MB/s eta 0:00:00
# Requirement already satisfied: idna in /usr/local/lib/python3.10/dist-packages (from httpx->scholarly) (3.4)
# Requirement already satisfied: sniffio in /usr/local/lib/python3.10/dist-packages (from httpx->scholarly) (1.3.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests[socks]->scholarly) (3.2.0)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests[socks]->scholarly) (2.0.4)
# Requirement already satisfied: PySocks!=1.5.7,>=1.5.6 in /usr/local/lib/python3.10/dist-packages (from requests[socks]->scholarly) (1.7.1)
# Collecting trio~=0.17 (from selenium->scholarly)
#   Downloading trio-0.22.2-py3-none-any.whl (400 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 400.2/400.2 kB 41.5 MB/s eta 0:00:00
# Collecting trio-websocket~=0.9 (from selenium->scholarly)
#   Downloading trio_websocket-0.10.3-py3-none-any.whl (17 kB)
# Requirement already satisfied: sphinx<8,>=1.6 in /usr/local/lib/python3.10/dist-packages (from sphinx-rtd-theme->scholarly) (5.0.2)
# Requirement already satisfied: docutils<0.19 in /usr/local/lib/python3.10/dist-packages (from sphinx-rtd-theme->scholarly) (0.18.1)
# Collecting sphinxcontrib-jquery<5,>=4 (from sphinx-rtd-theme->scholarly)
#   Downloading sphinxcontrib_jquery-4.1-py2.py3-none-any.whl (121 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 121.1/121.1 kB 17.8 MB/s eta 0:00:00
# Collecting h11<0.15,>=0.13 (from httpcore<0.18.0,>=0.15.0->httpx->scholarly)
#   Downloading h11-0.14.0-py3-none-any.whl (58 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 58.3/58.3 kB 8.8 MB/s eta 0:00:00
# Requirement already satisfied: anyio<5.0,>=3.0 in /usr/local/lib/python3.10/dist-packages (from httpcore<0.18.0,>=0.15.0->httpx->scholarly) (3.7.1)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.7.0->arrow->scholarly) (1.16.0)
# Requirement already satisfied: sphinxcontrib-applehelp in /usr/local/lib/python3.10/dist-packages (from sphinx<8,>=1.6->sphinx-rtd-theme->scholarly) (1.0.7)
# Requirement already satisfied: sphinxcontrib-devhelp in /usr/local/lib/python3.10/dist-packages (from sphinx<8,>=1.6->sphinx-rtd-theme->scholarly) (1.0.5)
# Requirement already satisfied: sphinxcontrib-jsmath in /usr/local/lib/python3.10/dist-packages (from sphinx<8,>=1.6->sphinx-rtd-theme->scholarly) (1.0.1)
# Requirement already satisfied: sphinxcontrib-htmlhelp>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from sphinx<8,>=1.6->sphinx-rtd-theme->scholarly) (2.0.4)
# Requirement already satisfied: sphinxcontrib-serializinghtml>=1.1.5 in /usr/local/lib/python3.10/dist-packages (from sphinx<8,>=1.6->sphinx-rtd-theme->scholarly) (1.1.8)
# Requirement already satisfied: sphinxcontrib-qthelp in /usr/local/lib/python3.10/dist-packages (from sphinx<8,>=1.6->sphinx-rtd-theme->scholarly) (1.0.6)
# Requirement already satisfied: Jinja2>=2.3 in /usr/local/lib/python3.10/dist-packages (from sphinx<8,>=1.6->sphinx-rtd-theme->scholarly) (3.1.2)
# Requirement already satisfied: Pygments>=2.0 in /usr/local/lib/python3.10/dist-packages (from sphinx<8,>=1.6->sphinx-rtd-theme->scholarly) (2.16.1)
# Requirement already satisfied: snowballstemmer>=1.1 in /usr/local/lib/python3.10/dist-packages (from sphinx<8,>=1.6->sphinx-rtd-theme->scholarly) (2.2.0)
# Requirement already satisfied: babel>=1.3 in /usr/local/lib/python3.10/dist-packages (from sphinx<8,>=1.6->sphinx-rtd-theme->scholarly) (2.12.1)
# Requirement already satisfied: alabaster<0.8,>=0.7 in /usr/local/lib/python3.10/dist-packages (from sphinx<8,>=1.6->sphinx-rtd-theme->scholarly) (0.7.13)
# Requirement already satisfied: imagesize in /usr/local/lib/python3.10/dist-packages (from sphinx<8,>=1.6->sphinx-rtd-theme->scholarly) (1.4.1)
# Requirement already satisfied: packaging in /usr/local/lib/python3.10/dist-packages (from sphinx<8,>=1.6->sphinx-rtd-theme->scholarly) (23.1)
# Requirement already satisfied: attrs>=20.1.0 in /usr/local/lib/python3.10/dist-packages (from trio~=0.17->selenium->scholarly) (23.1.0)
# Requirement already satisfied: sortedcontainers in /usr/local/lib/python3.10/dist-packages (from trio~=0.17->selenium->scholarly) (2.4.0)
# Collecting outcome (from trio~=0.17->selenium->scholarly)
#   Downloading outcome-1.2.0-py2.py3-none-any.whl (9.7 kB)
# Requirement already satisfied: exceptiongroup>=1.0.0rc9 in /usr/local/lib/python3.10/dist-packages (from trio~=0.17->selenium->scholarly) (1.1.3)
# Collecting wsproto>=0.14 (from trio-websocket~=0.9->selenium->scholarly)
#   Downloading wsproto-1.2.0-py3-none-any.whl (24 kB)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from Jinja2>=2.3->sphinx<8,>=1.6->sphinx-rtd-theme->scholarly) (2.1.3)
# Building wheels for collected packages: bibtexparser, free-proxy
#   Building wheel for bibtexparser (setup.py) ... done
#   Created wheel for bibtexparser: filename=bibtexparser-1.4.0-py3-none-any.whl size=42426 sha256=4b37ae80015d6f3ccd30656772bd2f1241946d847c6b61da29b442bcbee363b2
#   Stored in directory: /root/.cache/pip/wheels/5d/de/d5/4e42fd75d48106e7c4023d6594c2992db38afa7019f96139a2
#   Building wheel for free-proxy (setup.py) ... done
#   Created wheel for free-proxy: filename=free_proxy-1.1.1-py3-none-any.whl size=5637 sha256=b635df46bbe2df3409369868b5545f1497336a6f3c3ff9a1e388767458b7767d
#   Stored in directory: /root/.cache/pip/wheels/5a/96/c7/5a434714fff4fea9a59075428b142626e0a74f8c3bf90a50d0
# Successfully built bibtexparser free-proxy
# Installing collected packages: fake-useragent, python-dotenv, outcome, h11, deprecated, bibtexparser, wsproto, trio, httpcore, free-proxy, arrow, trio-websocket, httpx, selenium, sphinxcontrib-jquery, sphinx-rtd-theme, scholarly
# Successfully installed arrow-1.2.3 bibtexparser-1.4.0 deprecated-1.2.14 fake-useragent-1.2.1 free-proxy-1.1.1 h11-0.14.0 httpcore-0.17.3 httpx-0.24.1 outcome-1.2.0 python-dotenv-1.0.0 scholarly-1.7.11 selenium-4.11.2 sphinx-rtd-theme-1.3.0 sphinxcontrib-jquery-4.1 trio-0.22.2 trio-websocket-0.10.3 wsproto-1.2.0

# %%
import pandas as pd
from tqdm.notebook import tqdm
from scholarly import scholarly
from scholarly import ProxyGenerator

# Set up a ProxyGenerator object to use free proxies
# This needs to be done only once per session
pg = ProxyGenerator()
pg.FreeProxies()
scholarly.use_proxy(pg)
# Out:
# /usr/local/lib/python3.10/dist-packages/trio/_core/_multierror.py:412: RuntimeWarning: IPython detected, but you already have a custom exception handler installed. I'll skip installing Trio's custom handler, but this means exception groups will not show full tracebacks.
#   warnings.warn(

# %%
DEE = list(['Adolfo Herbster',
        'Alexandre Cunha Oliveira',
        'Alexandre Jean René Serres',
        'André Germano Dantas',
        'Angelo Perkusich',
        'Antônio do Nascimento Epaminondas',
        'Antonio M.N. Lima',
        'Benemar Alencar de Souza',
        'Bruno Barbosa Albert',
        'Célio Anésio da Silva',
        'Cursino Brandão Jacobina',
        'Damásio Fernandes Júnior',
        'Danilo F. S. Santos',
        'Edgar Roosevelt Braga Filho',
        'Edmar Candeia Gurjão',
        'Edson Guedes da Costa',
        'Edson Porto da Silva',
        'Fernanda Cecília Correia Lima Loureiro',
        'Francisco das Chagas Fernandes Guerra',
        'Francisco Marcos de Assis',
        'George Acioli Júnior',
        'George Rossany Soares de Lira',
        'Glauco Fontgalland',
        'Gutemberg Gonçalves dos Santos Júnior',
        'Helder A Pereira',
        'Jaidilson Jó da Silva',
        'Jalberth Fernandes de Araújo',
        'João Batista M Santos',
        'José Ewerton Pombo de Farias',
        'José Gutembergue de Assis Lira',
        'José Sérgio da Rocha Neto',
        'Karcius Marcelus Colaço Dantas',
        'Leimar de Oliveira',
        'Leocarlos Bezerra da Silva Lima',
        'Luciana Ribeiro Veloso',
        'Luis Reyes Rosales Montero',
        'Luiz Augusto Medeiros Martins Nóbrega',
        'Marcos Ricardo Alcântara Morais',
        'Mário de Sousa Araújo Filho',
        'Maurício Beltrão de Rossiter Correa',
        'Montiê Alves Vitorino',
        'Nubia Silva Dantas Brito',
        'Pablo Bezerra Vilar',
        'Pericles R. Barros',
        'Raimundo Carlos Silvério Freire',
        'Rafael Bezerra Correia Lima',
        'Raquel Aline Araújo Rodrigues',
        'Roberto Silva de Siqueira',
        'Rômulo Raimundo Maranhão do Valle',
        'Ronimack Trajano de Souza',
        'Saulo O. D. Luiz',
        'Talvanes Meneses de Oliveira',
        'Washington Luiz Araújo Neves',
        'Wamberto José Lira de Queiroz'])

# %%
df = pd.DataFrame(columns=['name', 'citations', 'h-index'])

for name in tqdm(DEE):
    try:
        search_query = scholarly.search_author(name)
        author = scholarly.fill(next(search_query))
        print(author['name']+' citations: '+ str(author['citedby'])+' h-index: '+ str(author['hindex']))
        df.loc[-1] =  [name, author['citedby'], author['hindex']]
        df.index = df.index + 1  # shifting index
        df = df.sort_index()  # sorting by index
    except:
        df.loc[-1] =  [name, 0, 0]
        df.index = df.index + 1  # shifting index
        df = df.sort_index()  # sorting by index

df = df[::-1].reset_index(drop=True)
# Out:
#   0%|          | 0/54 [00:00<?, ?it/s]
# Adolfo Herbster citations: 141 h-index: 6
# Alexandre Jean René Serres citations: 539 h-index: 15
# Angelo Perkusich citations: 2897 h-index: 27
# Antonio M.N. Lima citations: 8645 h-index: 43
# Benemar Alencar de Souza citations: 3193 h-index: 27
# Cursino Brandao Jacobina citations: 9664 h-index: 47
# Danilo F. S. Santos citations: 460 h-index: 11
# Edmar Candeia Gurjao citations: 267 h-index: 8
# Edson Guedes da Costa citations: 972 h-index: 17
# Edson Porto da Silva citations: 1493 h-index: 19
# FRANCISCO MARCOS DE ASSIS citations: 946 h-index: 14
# George Acioli Junior citations: 169 h-index: 8
# George Rossany Soares de Lira citations: 387 h-index: 11
# Glauco Fontgalland citations: 973 h-index: 14
# Gutemberg Gonçalves dos Santos Júnior citations: 138 h-index: 7
# Helder A. Pereira citations: 561 h-index: 12
# Jaidilson Jó da Silva citations: 293 h-index: 10
# João Batista M Santos citations: 163 h-index: 7
# Jose Sergio da Rocha Neto citations: 739 h-index: 15
# Karcius Marcelus Colaço Dantas citations: 541 h-index: 11
# Luis Reyes Rosales Montero citations: 27 h-index: 3
# Montiê Alves Vitorino citations: 1046 h-index: 15
# Nubia Silva Dantas Brito citations: 2135 h-index: 20
# Pericles R. Barros citations: 694 h-index: 13
# Raimundo Carlos Silvério Freire citations: 2420 h-index: 23
# Saulo O. D. Luiz citations: 167 h-index: 7
# Wamberto José Lira de Queiroz citations: 272 h-index: 9

# %%
df.sort_values('citations', ascending=False)[::1].reset_index(drop=True)
# Out:
#                                       name  citations  h-index
# 0                 Cursino Brandão Jacobina       9664       47
# 1                        Antonio M.N. Lima       8645       43
# 2                 Benemar Alencar de Souza       3193       27
# 3                         Angelo Perkusich       2897       27
# 4          Raimundo Carlos Silvério Freire       2420       23
# 5                 Nubia Silva Dantas Brito       2135       20
# 6                     Edson Porto da Silva       1493       19
# 7                    Montiê Alves Vitorino       1046       15
# 8                       Glauco Fontgalland        973       14
# 9                    Edson Guedes da Costa        972       17
# 10               Francisco Marcos de Assis        946       14
# 11               José Sérgio da Rocha Neto        739       15
# 12                      Pericles R. Barros        694       13
# 13                        Helder A Pereira        561       12
# 14          Karcius Marcelus Colaço Dantas        541       11
# 15              Alexandre Jean René Serres        539       15
# 16                     Danilo F. S. Santos        460       11
# 17           George Rossany Soares de Lira        387       11
# 18                   Jaidilson Jó da Silva        293       10
# 19           Wamberto José Lira de Queiroz        272        9
# 20                    Edmar Candeia Gurjão        267        8
# 21                    George Acioli Júnior        169        8
# 22                        Saulo O. D. Luiz        167        7
# 23                   João Batista M Santos        163        7
# 24                         Adolfo Herbster        141        6
# 25   Gutemberg Gonçalves dos Santos Júnior        138        7
# 26              Luis Reyes Rosales Montero         27        3
# 27            Jalberth Fernandes de Araújo          0        0
# 28                   Célio Anésio da Silva          0        0
# 29            Washington Luiz Araújo Neves          0        0
# 30            Talvanes Meneses de Oliveira          0        0
# 31                    André Germano Dantas          0        0
# 32               Ronimack Trajano de Souza          0        0
# 33       Rômulo Raimundo Maranhão do Valle          0        0
# 34               Roberto Silva de Siqueira          0        0
# 35           Raquel Aline Araújo Rodrigues          0        0
# 36             Rafael Bezerra Correia Lima          0        0
# 37       Antônio do Nascimento Epaminondas          0        0
# 38                    Bruno Barbosa Albert          0        0
# 39                     Pablo Bezerra Vilar          0        0
# 40                Damásio Fernandes Júnior          0        0
# 41                Alexandre Cunha Oliveira          0        0
# 42   Francisco das Chagas Fernandes Guerra          0        0
# 43             Mário de Sousa Araújo Filho          0        0
# 44         Marcos Ricardo Alcântara Morais          0        0
# 45   Luiz Augusto Medeiros Martins Nóbrega          0        0
# 46                  Luciana Ribeiro Veloso          0        0
# 47         Leocarlos Bezerra da Silva Lima          0        0
# 48                      Leimar de Oliveira          0        0
# 49             Edgar Roosevelt Braga Filho          0        0
# 50  Fernanda Cecília Correia Lima Loureiro          0        0
# 51          José Gutembergue de Assis Lira          0        0
# 52            José Ewerton Pombo de Farias          0        0
# 53     Maurício Beltrão de Rossiter Correa          0        0

# %%
df
# Out:
#                                       name  citations  h-index
# 0                          Adolfo Herbster        141        6
# 1                 Alexandre Cunha Oliveira          0        0
# 2               Alexandre Jean René Serres        539       15
# 3                     André Germano Dantas          0        0
# 4                         Angelo Perkusich       2897       27
# 5        Antônio do Nascimento Epaminondas          0        0
# 6                        Antonio M.N. Lima       8645       43
# 7                 Benemar Alencar de Souza       3193       27
# 8                     Bruno Barbosa Albert          0        0
# 9                    Célio Anésio da Silva          0        0
# 10                Cursino Brandão Jacobina       9664       47
# 11                Damásio Fernandes Júnior          0        0
# 12                     Danilo F. S. Santos        460       11
# 13             Edgar Roosevelt Braga Filho          0        0
# 14                    Edmar Candeia Gurjão        267        8
# 15                   Edson Guedes da Costa        972       17
# 16                    Edson Porto da Silva       1493       19
# 17  Fernanda Cecília Correia Lima Loureiro          0        0
# 18   Francisco das Chagas Fernandes Guerra          0        0
# 19               Francisco Marcos de Assis        946       14
# 20                    George Acioli Júnior        169        8
# 21           George Rossany Soares de Lira        387       11
# 22                      Glauco Fontgalland        973       14
# 23   Gutemberg Gonçalves dos Santos Júnior        138        7
# 24                        Helder A Pereira        561       12
# 25                   Jaidilson Jó da Silva        293       10
# 26            Jalberth Fernandes de Araújo          0        0
# 27                   João Batista M Santos        163        7
# 28            José Ewerton Pombo de Farias          0        0
# 29          José Gutembergue de Assis Lira          0        0
# 30               José Sérgio da Rocha Neto        739       15
# 31          Karcius Marcelus Colaço Dantas        541       11
# 32                      Leimar de Oliveira          0        0
# 33         Leocarlos Bezerra da Silva Lima          0        0
# 34                  Luciana Ribeiro Veloso          0        0
# 35              Luis Reyes Rosales Montero         27        3
# 36   Luiz Augusto Medeiros Martins Nóbrega          0        0
# 37         Marcos Ricardo Alcântara Morais          0        0
# 38             Mário de Sousa Araújo Filho          0        0
# 39     Maurício Beltrão de Rossiter Correa          0        0
# 40                   Montiê Alves Vitorino       1046       15
# 41                Nubia Silva Dantas Brito       2135       20
# 42                     Pablo Bezerra Vilar          0        0
# 43                      Pericles R. Barros        694       13
# 44         Raimundo Carlos Silvério Freire       2420       23
# 45             Rafael Bezerra Correia Lima          0        0
# 46           Raquel Aline Araújo Rodrigues          0        0
# 47               Roberto Silva de Siqueira          0        0
# 48       Rômulo Raimundo Maranhão do Valle          0        0
# 49               Ronimack Trajano de Souza          0        0
# 50                        Saulo O. D. Luiz        167        7
# 51            Talvanes Meneses de Oliveira          0        0
# 52            Washington Luiz Araújo Neves          0        0
# 53           Wamberto José Lira de Queiroz        272        9

# %%
scholarly.search_org('Federal University of Campina Grande')
# Out:
# [{'Organization': 'Universidade Federal de Campina Grande',
#   'id': '17170101166133751793'}]
