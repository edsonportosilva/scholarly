# %% [markdown]
# <a href="https://colab.research.google.com/github/edsonportosilva/scholarly/blob/main/Jupyter/Google%20Scholar%20data.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
! pip3 install scholarly
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting scholarly
#   Downloading scholarly-1.7.11-py3-none-any.whl (39 kB)
# Collecting httpx
#   Downloading httpx-0.24.0-py3-none-any.whl (75 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 75.3/75.3 kB 5.8 MB/s eta 0:00:00
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.10/dist-packages (from scholarly) (4.5.0)
# Collecting bibtexparser
#   Downloading bibtexparser-1.4.0.tar.gz (51 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 51.9/51.9 kB 3.2 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Collecting free-proxy
#   Downloading free_proxy-1.1.1.tar.gz (5.1 kB)
#   Preparing metadata (setup.py) ... done
# Collecting python-dotenv
#   Downloading python_dotenv-1.0.0-py3-none-any.whl (19 kB)
# Collecting arrow
#   Downloading arrow-1.2.3-py3-none-any.whl (66 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 66.4/66.4 kB 3.6 MB/s eta 0:00:00
# Requirement already satisfied: requests[socks] in /usr/local/lib/python3.10/dist-packages (from scholarly) (2.27.1)
# Requirement already satisfied: beautifulsoup4 in /usr/local/lib/python3.10/dist-packages (from scholarly) (4.11.2)
# Collecting sphinx-rtd-theme
#   Downloading sphinx_rtd_theme-1.2.0-py2.py3-none-any.whl (2.8 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.8/2.8 MB 41.7 MB/s eta 0:00:00
# Collecting selenium
#   Downloading selenium-4.9.0-py3-none-any.whl (6.5 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.5/6.5 MB 18.6 MB/s eta 0:00:00
# Collecting deprecated
#   Downloading Deprecated-1.2.13-py2.py3-none-any.whl (9.6 kB)
# Collecting fake-useragent
#   Downloading fake_useragent-1.1.3-py3-none-any.whl (50 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 50.5/50.5 kB 1.7 MB/s eta 0:00:00
# Requirement already satisfied: python-dateutil>=2.7.0 in /usr/local/lib/python3.10/dist-packages (from arrow->scholarly) (2.8.2)
# Requirement already satisfied: soupsieve>1.2 in /usr/local/lib/python3.10/dist-packages (from beautifulsoup4->scholarly) (2.4.1)
# Requirement already satisfied: pyparsing>=2.0.3 in /usr/local/lib/python3.10/dist-packages (from bibtexparser->scholarly) (3.0.9)
# Requirement already satisfied: wrapt<2,>=1.10 in /usr/local/lib/python3.10/dist-packages (from deprecated->scholarly) (1.14.1)
# Requirement already satisfied: lxml in /usr/local/lib/python3.10/dist-packages (from free-proxy->scholarly) (4.9.2)
# Requirement already satisfied: sniffio in /usr/local/lib/python3.10/dist-packages (from httpx->scholarly) (1.3.0)
# Collecting httpcore<0.18.0,>=0.15.0
#   Downloading httpcore-0.17.0-py3-none-any.whl (70 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 70.6/70.6 kB 3.1 MB/s eta 0:00:00
# Requirement already satisfied: certifi in /usr/local/lib/python3.10/dist-packages (from httpx->scholarly) (2022.12.7)
# Requirement already satisfied: idna in /usr/local/lib/python3.10/dist-packages (from httpx->scholarly) (3.4)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests[socks]->scholarly) (1.26.15)
# Requirement already satisfied: charset-normalizer~=2.0.0 in /usr/local/lib/python3.10/dist-packages (from requests[socks]->scholarly) (2.0.12)
# Requirement already satisfied: PySocks!=1.5.7,>=1.5.6 in /usr/local/lib/python3.10/dist-packages (from requests[socks]->scholarly) (1.7.1)
# Collecting trio~=0.17
#   Downloading trio-0.22.0-py3-none-any.whl (384 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 384.9/384.9 kB 20.6 MB/s eta 0:00:00
# Collecting trio-websocket~=0.9
#   Downloading trio_websocket-0.10.2-py3-none-any.whl (17 kB)
# Requirement already satisfied: sphinx<7,>=1.6 in /usr/local/lib/python3.10/dist-packages (from sphinx-rtd-theme->scholarly) (3.5.4)
# Collecting sphinxcontrib-jquery!=3.0.0,>=2.0.0
#   Downloading sphinxcontrib_jquery-4.1-py2.py3-none-any.whl (121 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 121.1/121.1 kB 5.0 MB/s eta 0:00:00
# Requirement already satisfied: docutils<0.19 in /usr/local/lib/python3.10/dist-packages (from sphinx-rtd-theme->scholarly) (0.16)
# Requirement already satisfied: anyio<5.0,>=3.0 in /usr/local/lib/python3.10/dist-packages (from httpcore<0.18.0,>=0.15.0->httpx->scholarly) (3.6.2)
# Collecting h11<0.15,>=0.13
#   Downloading h11-0.14.0-py3-none-any.whl (58 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 58.3/58.3 kB 2.8 MB/s eta 0:00:00
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.7.0->arrow->scholarly) (1.16.0)
# Requirement already satisfied: sphinxcontrib-devhelp in /usr/local/lib/python3.10/dist-packages (from sphinx<7,>=1.6->sphinx-rtd-theme->scholarly) (1.0.2)
# Requirement already satisfied: babel>=1.3 in /usr/local/lib/python3.10/dist-packages (from sphinx<7,>=1.6->sphinx-rtd-theme->scholarly) (2.12.1)
# Requirement already satisfied: snowballstemmer>=1.1 in /usr/local/lib/python3.10/dist-packages (from sphinx<7,>=1.6->sphinx-rtd-theme->scholarly) (2.2.0)
# Requirement already satisfied: alabaster<0.8,>=0.7 in /usr/local/lib/python3.10/dist-packages (from sphinx<7,>=1.6->sphinx-rtd-theme->scholarly) (0.7.13)
# Requirement already satisfied: sphinxcontrib-qthelp in /usr/local/lib/python3.10/dist-packages (from sphinx<7,>=1.6->sphinx-rtd-theme->scholarly) (1.0.3)
# Requirement already satisfied: packaging in /usr/local/lib/python3.10/dist-packages (from sphinx<7,>=1.6->sphinx-rtd-theme->scholarly) (23.1)
# Requirement already satisfied: sphinxcontrib-htmlhelp in /usr/local/lib/python3.10/dist-packages (from sphinx<7,>=1.6->sphinx-rtd-theme->scholarly) (2.0.1)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.10/dist-packages (from sphinx<7,>=1.6->sphinx-rtd-theme->scholarly) (67.7.2)
# Requirement already satisfied: Pygments>=2.0 in /usr/local/lib/python3.10/dist-packages (from sphinx<7,>=1.6->sphinx-rtd-theme->scholarly) (2.14.0)
# Requirement already satisfied: Jinja2>=2.3 in /usr/local/lib/python3.10/dist-packages (from sphinx<7,>=1.6->sphinx-rtd-theme->scholarly) (3.1.2)
# Requirement already satisfied: imagesize in /usr/local/lib/python3.10/dist-packages (from sphinx<7,>=1.6->sphinx-rtd-theme->scholarly) (1.4.1)
# Requirement already satisfied: sphinxcontrib-jsmath in /usr/local/lib/python3.10/dist-packages (from sphinx<7,>=1.6->sphinx-rtd-theme->scholarly) (1.0.1)
# Requirement already satisfied: sphinxcontrib-applehelp in /usr/local/lib/python3.10/dist-packages (from sphinx<7,>=1.6->sphinx-rtd-theme->scholarly) (1.0.4)
# Requirement already satisfied: sphinxcontrib-serializinghtml in /usr/local/lib/python3.10/dist-packages (from sphinx<7,>=1.6->sphinx-rtd-theme->scholarly) (1.1.5)
# Requirement already satisfied: sortedcontainers in /usr/local/lib/python3.10/dist-packages (from trio~=0.17->selenium->scholarly) (2.4.0)
# Collecting outcome
#   Downloading outcome-1.2.0-py2.py3-none-any.whl (9.7 kB)
# Requirement already satisfied: attrs>=19.2.0 in /usr/local/lib/python3.10/dist-packages (from trio~=0.17->selenium->scholarly) (23.1.0)
# Requirement already satisfied: exceptiongroup>=1.0.0rc9 in /usr/local/lib/python3.10/dist-packages (from trio~=0.17->selenium->scholarly) (1.1.1)
# Collecting async-generator>=1.9
#   Downloading async_generator-1.10-py3-none-any.whl (18 kB)
# Collecting wsproto>=0.14
#   Downloading wsproto-1.2.0-py3-none-any.whl (24 kB)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from Jinja2>=2.3->sphinx<7,>=1.6->sphinx-rtd-theme->scholarly) (2.1.2)
# Building wheels for collected packages: bibtexparser, free-proxy
#   Building wheel for bibtexparser (setup.py) ... done
#   Created wheel for bibtexparser: filename=bibtexparser-1.4.0-py3-none-any.whl size=42444 sha256=8ccdf286fe82efb49832e6afe4d94250620cd311a553264de335928ff12b0f88
#   Stored in directory: /root/.cache/pip/wheels/5d/de/d5/4e42fd75d48106e7c4023d6594c2992db38afa7019f96139a2
#   Building wheel for free-proxy (setup.py) ... done
#   Created wheel for free-proxy: filename=free_proxy-1.1.1-py3-none-any.whl size=5652 sha256=8360e72bef8b26c43de60a4f3cf59296c5c2677660ae93167ef23e156d933c27
#   Stored in directory: /root/.cache/pip/wheels/5a/96/c7/5a434714fff4fea9a59075428b142626e0a74f8c3bf90a50d0
# Successfully built bibtexparser free-proxy
# Installing collected packages: fake-useragent, python-dotenv, outcome, h11, deprecated, bibtexparser, async-generator, wsproto, trio, httpcore, free-proxy, arrow, trio-websocket, sphinxcontrib-jquery, httpx, sphinx-rtd-theme, selenium, scholarly
# Successfully installed arrow-1.2.3 async-generator-1.10 bibtexparser-1.4.0 deprecated-1.2.13 fake-useragent-1.1.3 free-proxy-1.1.1 h11-0.14.0 httpcore-0.17.0 httpx-0.24.0 outcome-1.2.0 python-dotenv-1.0.0 scholarly-1.7.11 selenium-4.9.0 sphinx-rtd-theme-1.2.0 sphinxcontrib-jquery-4.1 trio-0.22.0 trio-websocket-0.10.2 wsproto-1.2.0

# %%
import pandas as pd
from tqdm.notebook import tqdm
from scholarly import scholarly
from scholarly import ProxyGenerator

# Set up a ProxyGenerator object to use free proxies
# This needs to be done only once per session
pg = ProxyGenerator()
pg.FreeProxies()
scholarly.use_proxy(pg)

# %%
DEE = list(['Adolfo Herbster',
        'Alexandre Cunha Oliveira', 
        'Alexandre Jean René Serres', 
        'André Germano Dantas',
        'Angelo Perkusich',
        'Antônio do Nascimento Epaminondas',
        'Antonio M.N. Lima',
        'Benemar Alencar de Souza',
        'Bruno Barbosa Albert',       
        'Célio Anésio da Silva',
        'Cursino Brandão Jacobina',
        'Damásio Fernandes Júnior',
        'Danilo F. S. Santos',
        'Edgar Roosevelt Braga Filho',
        'Edmar Candeia Gurjão',
        'Edson Guedes da Costa',
        'Edson Porto da Silva',
        'Fernanda Cecília Correia Lima Loureiro',
        'Francisco das Chagas Fernandes Guerra',
        'Francisco Marcos de Assis',
        'George Acioli Júnior',
        'George Rossany Soares de Lira',
        'Glauco Fontgalland',
        'Gutemberg Gonçalves dos Santos Júnior',
        'Helder A Pereira',
        'Jaidilson Jó da Silva',
        'Jalberth Fernandes de Araújo',
        'João Batista M Santos',
        'José Ewerton Pombo de Farias',
        'José Gutembergue de Assis Lira',
        'José Sérgio da Rocha Neto',
        'Karcius Marcelus Colaço Dantas',
        'Leimar de Oliveira',
        'Leocarlos Bezerra da Silva Lima',
        'Luciana Ribeiro Veloso',
        'Luis Reyes Rosales Montero',
        'Luiz Augusto Medeiros Martins Nóbrega',
        'Marcos Ricardo Alcântara Morais',
        'Mário de Sousa Araújo Filho',
        'Maurício Beltrão de Rossiter Correa',
        'Montiê Alves Vitorino',
        'Núbia Silva Dantas Brito',
        'Pablo Bezerra Vilar',
        'Péricles R. Barros',
        'Raimundo Carlos Silvério Freire',
        'Rafael Bezerra Correia Lima',
        'Raquel Aline Araújo Rodrigues',
        'Roberto Silva de Siqueira',
        'Rômulo Raimundo Maranhão do Valle',
        'Ronimack Trajano de Souza',
        'Saulo O. D. Luiz',
        'Talvanes Meneses de Oliveira',
        'Washington Luiz Araújo Neves',
        'Wamberto José Lira de Queiroz'])

# %%
df = pd.DataFrame(columns=['name', 'citations', 'h-index'])

for name in tqdm(DEE):
    try:
        search_query = scholarly.search_author(name)
        author = scholarly.fill(next(search_query))
#         print(author['name']+' citations: '+ str(author['citedby'])+' h-index: '+ str(author['hindex']))
        df.loc[-1] =  [name, author['citedby'], author['hindex']]
        df.index = df.index + 1  # shifting index
        df = df.sort_index()  # sorting by index
    except:
        df.loc[-1] =  [name, 0, 0]
        df.index = df.index + 1  # shifting index
        df = df.sort_index()  # sorting by index
        
df = df[::-1].reset_index(drop=True)
# Out:
#   0%|          | 0/54 [00:00<?, ?it/s]

# %%
df.sort_values('citations', ascending=False)[::1].reset_index(drop=True)
# Out:
#                                       name  citations  h-index
# 0                 Cursino Brandão Jacobina       9538       46
# 1                        Antonio M.N. Lima       8526       43
# 2                 Benemar Alencar de Souza       3093       27
# 3                         Angelo Perkusich       2796       27
# 4          Raimundo Carlos Silvério Freire       2299       23
# 5                 Núbia Silva Dantas Brito       2051       20
# 6                     Edson Porto da Silva       1406       19
# 7                    Montiê Alves Vitorino       1004       15
# 8                    Edson Guedes da Costa        917       17
# 9                       Glauco Fontgalland        909       14
# 10               Francisco Marcos de Assis        904       14
# 11               José Sérgio da Rocha Neto        734       15
# 12              Alexandre Jean René Serres        586       15
# 13                        Helder A Pereira        550       12
# 14          Karcius Marcelus Colaço Dantas        511       10
# 15                     Danilo F. S. Santos        431       11
# 16           George Rossany Soares de Lira        358       11
# 17                   Jaidilson Jó da Silva        293       10
# 18           Wamberto José Lira de Queiroz        264        9
# 19                    Edmar Candeia Gurjão        257        9
# 20                    George Acioli Júnior        167        8
# 21                   João Batista M Santos        159        7
# 22                        Saulo O. D. Luiz        158        7
# 23                         Adolfo Herbster        138        6
# 24   Gutemberg Gonçalves dos Santos Júnior        135        7
# 25              Luis Reyes Rosales Montero         26        3
# 26            Talvanes Meneses de Oliveira          0        0
# 27            Washington Luiz Araújo Neves          0        0
# 28               Ronimack Trajano de Souza          0        0
# 29       Rômulo Raimundo Maranhão do Valle          0        0
# 30               Roberto Silva de Siqueira          0        0
# 31     Maurício Beltrão de Rossiter Correa          0        0
# 32             Rafael Bezerra Correia Lima          0        0
# 33                    André Germano Dantas          0        0
# 34                 Péricles Rezende Barros          0        0
# 35                     Pablo Bezerra Vilar          0        0
# 36       Antônio do Nascimento Epaminondas          0        0
# 37                    Bruno Barbosa Albert          0        0
# 38           Raquel Aline Araújo Rodrigues          0        0
# 39   Francisco das Chagas Fernandes Guerra          0        0
# 40         Marcos Ricardo Alcântara Morais          0        0
# 41   Luiz Augusto Medeiros Martins Nóbrega          0        0
# 42                  Luciana Ribeiro Veloso          0        0
# 43         Leocarlos Bezerra da Silva Lima          0        0
# 44                      Leimar de Oliveira          0        0
# 45                   Célio Anésio da Silva          0        0
# 46                Damásio Fernandes Júnior          0        0
