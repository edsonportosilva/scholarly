# %% [markdown]
# <a href="https://colab.research.google.com/github/edsonportosilva/scholarly/blob/main/Jupyter/Google%20Scholar%20data.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
! pip3 install scholarly
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 66.4/66.4 kB 3.8 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 55.1/55.1 kB 5.3 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# ...
#   Preparing metadata (setup.py) ... done
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 75.6/75.6 kB 6.1 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 9.5/9.5 MB 26.1 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.8/2.8 MB 45.0 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 77.9/77.9 kB 5.5 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 58.3/58.3 kB 5.9 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 467.2/467.2 kB 29.9 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 121.1/121.1 kB 10.8 MB/s eta 0:00:00
# ...
#   Created wheel for bibtexparser: filename=bibtexparser-1.4.1-py3-none-any.whl size=43253 sha256=ed346f3bb60e750c101b74825798f8d4cb200fa091e72d1f68733b1fe211a539
# ...

# %%
import pandas as pd
from tqdm.notebook import tqdm
from scholarly import scholarly
from scholarly import ProxyGenerator

# Set up a ProxyGenerator object to use free proxies
# This needs to be done only once per session
pg = ProxyGenerator()
pg.FreeProxies()
scholarly.use_proxy(pg)

# %%
DEE = list(['Adolfo Herbster',
        'Alexandre Cunha Oliveira',
        'Alexandre Jean René Serres',
        'André Germano Dantas',
        'Angelo Perkusich',
        'Antônio do Nascimento Epaminondas',
        'Antonio M.N. Lima',
        'Benemar Alencar de Souza',
        'Bruno Barbosa Albert',
        'Célio Anésio da Silva',
        'Cursino Brandão Jacobina',
        'Damásio Fernandes Júnior',
        'Danilo F. S. Santos',
        'Edgar Roosevelt Braga Filho',
        'Edmar Candeia Gurjão',
        'Edson Guedes da Costa',
        'Edson Porto da Silva',
        'Fernanda Cecília Correia Lima Loureiro',
        'Francisco Marcos de Assis',
        'George Acioli Júnior',
        'George Rossany Soares de Lira',
        'Glauco Fontgalland',
        'Gutemberg Gonçalves dos Santos Júnior',
        'Helder A Pereira',
        'Jaidilson Jó da Silva',
        'Jalberth Fernandes de Araújo',
        'João Batista M Santos',
        'José Ewerton Pombo de Farias',
        'José Gutembergue de Assis Lira',
        'Karcius Marcelus Colaço Dantas',
        'Leimar de Oliveira',
        'Leocarlos Bezerra da Silva Lima',
        'Luciana Ribeiro Veloso',
        'Luis Reyes Rosales Montero',
        'Luiz Augusto Medeiros Martins Nóbrega',
        'Marcos Ricardo Alcântara Morais',
        'Mário de Sousa Araújo Filho',
        'Montiê Alves Vitorino',
        'Nubia Silva Dantas Brito',
        'Pablo Bezerra Vilar',
        'Pericles R. Barros',
        'Raimundo Carlos Silvério Freire',
        'Rafael Bezerra Correia Lima',
        'Raquel Aline Araújo Rodrigues',
        'Roberto Silva de Siqueira',
        'Rômulo Raimundo Maranhão do Valle',
        'Ronimack Trajano de Souza',
        'Saulo O. D. Luiz',
        'Talvanes Meneses de Oliveira',
        'Washington Luiz Araújo Neves',
        'Wamberto José Lira de Queiroz'])

# %%
df = pd.DataFrame(columns=['name', 'citations', 'h-index'])

for name in tqdm(DEE):
    try:
        search_query = scholarly.search_author(name)
        author = scholarly.fill(next(search_query))
        print(author['name']+' citations: '+ str(author['citedby'])+' h-index: '+ str(author['hindex']))
        df.loc[-1] =  [name, author['citedby'], author['hindex']]
        df.index = df.index + 1  # shifting index
        df = df.sort_index()  # sorting by index
    except:
        df.loc[-1] =  [name, 0, 0]
        df.index = df.index + 1  # shifting index
        df = df.sort_index()  # sorting by index

df = df[::-1].reset_index(drop=True)
# Out:
#   0%|          | 0/51 [00:00<?, ?it/s]
# Adolfo Herbster citations: 153 h-index: 6
# Alexandre Cunha Oliveira citations: 1396 h-index: 15
# Alexandre Jean René Serres citations: 657 h-index: 16
# Angelo Perkusich citations: 3239 h-index: 28
# Antonio M.N. Lima citations: 8970 h-index: 45
# Benemar Alencar de Souza citations: 3387 h-index: 29
# Cursino Brandao Jacobina citations: 10094 h-index: 47
# Danilo F. S. Santos citations: 540 h-index: 12
# Edmar Candeia Gurjao citations: 311 h-index: 9
# Edson Guedes da Costa citations: 1075 h-index: 18
# Edson Porto da Silva citations: 1639 h-index: 19
# FRANCISCO MARCOS DE ASSIS citations: 995 h-index: 15
# George Acioli Junior citations: 192 h-index: 9
# George Rossany Soares de Lira citations: 421 h-index: 11
# Glauco Fontgalland citations: 1115 h-index: 15
# Gutemberg Gonçalves dos Santos Júnior citations: 143 h-index: 7
# Helder A. Pereira citations: 600 h-index: 12
# Jaidilson Jó da Silva citations: 309 h-index: 10
# ...

# %%
df.sort_values('citations', ascending=False)[::1].reset_index(drop=True)
# Out:
#                                       name  citations  h-index
# 0                 Cursino Brandão Jacobina      10094       47
# 1                        Antonio M.N. Lima       8970       45
# 2                 Benemar Alencar de Souza       3387       29
# 3                         Angelo Perkusich       3239       28
# 4          Raimundo Carlos Silvério Freire       2623       25
# 5                 Nubia Silva Dantas Brito       2302       21
# 6                     Edson Porto da Silva       1639       19
# 7                 Alexandre Cunha Oliveira       1396       15
# 8                    Montiê Alves Vitorino       1136       16
# 9                       Glauco Fontgalland       1115       15
# 10                   Edson Guedes da Costa       1075       18
# 11               Francisco Marcos de Assis        995       15
# 12                      Pericles R. Barros        761       13
# 13              Alexandre Jean René Serres        657       16
# ...

# %%
df
# Out:
#                                       name  citations  h-index
# 0                          Adolfo Herbster          0        0
# 1                 Alexandre Cunha Oliveira       1396       15
# 2               Alexandre Jean René Serres        657       16
# 3                     André Germano Dantas          0        0
# 4                         Angelo Perkusich          0        0
# 5        Antônio do Nascimento Epaminondas          0        0
# 6                        Antonio M.N. Lima          0        0
# 7                 Benemar Alencar de Souza          0        0
# 8                     Bruno Barbosa Albert          0        0
# 9                    Célio Anésio da Silva          0        0
# 10                Cursino Brandão Jacobina          0        0
# 11                Damásio Fernandes Júnior          0        0
# 12                     Danilo F. S. Santos          0        0
# 13             Edgar Roosevelt Braga Filho          0        0
# ...

# %%
scholarly.search_org('Federal University of Campina Grande')
# Out:
# ---------------------------------------------------------------------------
# MaxTriesExceededException                 Traceback (most recent call last)
# <ipython-input-7-4006c9c6111d> in <cell line: 1>()
# ----> 1 scholarly.search_org('Federal University of Campina Grande')
#
# /usr/local/lib/python3.10/dist-packages/scholarly/_scholarly.py in search_org(self, name, fromauthor)
#     515
#     516         url = _AUTHSEARCH.format(requests.utils.quote(name))
# --> 517         return self.__nav.search_organization(url, fromauthor)
#     518
#     519     def search_author_by_organization(self, organization_id: int):
#
# /usr/local/lib/python3.10/dist-packages/scholarly/_navigator.py in search_organization(self, url, fromauthor)
#     322            to get institution/organization name.
#     323         """
# --> 324         soup = self._get_soup(url)
#     325         rows = soup.find_all('h3', 'gsc_inst_res')
#     326         if rows:
#
# ...
